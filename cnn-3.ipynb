# %%
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
import numpy as np

from sklearn.metrics import classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Dense,
    Flatten,
    Conv2D,
    MaxPooling2D,
    Dropout,
    BatchNormalization,
    Input,
    RandomFlip,
    RandomRotation,
    RandomZoom
)
from tensorflow.keras.metrics import BinaryAccuracy
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %%
seed = 1000
batch_size = 64

# %%
plt.rc("figure", autolayout=True)
plt.rc(
    "axes",
    labelweight="bold",
    labelsize="large",
    titleweight="bold",
    titlesize=18,
    titlepad=10,
)
plt.rc("image", cmap="magma")

# %% [markdown]
# # Dataset
#
# A princípio, os dados serão separados apenas em treinamento e teste

# %%
train_base, test_base = image_dataset_from_directory(
    directory="./dataset",
    labels="inferred",
    label_mode="binary",
    color_mode="rgb",
    image_size=(256, 256),
    batch_size=batch_size,
    shuffle=True,
    seed=seed,
    validation_split=0.2,
    subset="both",
    pad_to_aspect_ratio=True,
    verbose=True,
)
# Out:
# Found 923 files belonging to 2 classes.
# Using 739 files for training.
# Using 184 files for validation.

# %% [markdown]
# Normalização dos pixels

# %%
X_train = train_base.map(lambda x, y: (x / 255.0, y))
X_test = test_base.map(lambda x, y: (x / 255.0, y))

# %% [markdown]
# # Modelo

# %%
model = Sequential([
    Input(shape=(256, 256, 3)),
	RandomFlip(mode="horizontal", seed=seed),
    Conv2D(filters=32, kernel_size=(3, 3), activation="relu", kernel_initializer="he_normal", padding="same"),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(filters=32, kernel_size=(3, 3), activation="relu", kernel_initializer="he_normal", padding="same"),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(filters=64, kernel_size=(3, 3), activation="relu", kernel_initializer="he_normal", padding="same"),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(filters=64, kernel_size=(3, 3), activation="relu", kernel_initializer="he_normal", padding="same"),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(filters=128, kernel_size=(3, 3), activation="relu", kernel_initializer="he_normal", padding="same"),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Flatten(),
    Dense(units=1024, activation="relu", kernel_initializer="he_normal"),
    Dropout(0.2),
    Dense(units=512, activation="relu", kernel_initializer="he_normal"),
    Dropout(0.2),
    Dense(units=128, activation="relu", kernel_initializer="he_normal"),
    Dense(units=1, activation="sigmoid")
])

model.compile(
    optimizer="adam", loss="binary_crossentropy", metrics=[BinaryAccuracy()]
)

model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ random_flip_3 (RandomFlip)      │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 256, 256, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_15          │ (None, 256, 256, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_15 (MaxPooling2D) │ (None, 128, 128, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_16 (Conv2D)              │ (None, 128, 128, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_16          │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_16 (MaxPooling2D) │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_17 (Conv2D)              │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_17          │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_17 (MaxPooling2D) │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_18 (Conv2D)              │ (None, 32, 32, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_18          │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_18 (MaxPooling2D) │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_19 (Conv2D)              │ (None, 16, 16, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_19          │ (None, 16, 16, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_19 (MaxPooling2D) │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 1024)           │     8,389,632 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 128)            │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,120,929 (34.79 MB)
#  Trainable params: 9,120,289 (34.79 MB)
#  Non-trainable params: 640 (2.50 KB)

# %% [markdown]
# CallBacks

# %%
es = EarlyStopping(
    monitor="val_binary_accuracy", patience=40, restore_best_weights=True, verbose=1
)

rlr = ReduceLROnPlateau(monitor="val_binary_accuracy", factor=0.2, patience=20, verbose=True)

# %%
history = model.fit(
    X_train,
    validation_data=X_test,
    epochs=200,
    callbacks=[es, rlr],
)
# Out:
# Epoch 1/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - binary_accuracy: 0.5799 - loss: 3.9304 - val_binary_accuracy: 0.5054 - val_loss: 1.1352 - learning_rate: 0.0010
# Epoch 2/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - binary_accuracy: 0.7126 - loss: 0.7580 - val_binary_accuracy: 0.6739 - val_loss: 0.5944 - learning_rate: 0.0010
# Epoch 3/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - binary_accuracy: 0.7811 - loss: 0.4970 - val_binary_accuracy: 0.7120 - val_loss: 0.6045 - learning_rate: 0.0010
# Epoch 4/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - binary_accuracy: 0.7658 - loss: 0.5155 - val_binary_accuracy: 0.6739 - val_loss: 0.6114 - learning_rate: 0.0010
# Epoch 5/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - binary_accuracy: 0.8058 - loss: 0.4371 - val_binary_accuracy: 0.5761 - val_loss: 0.8123 - learning_rate: 0.0010
# Epoch 6/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - binary_accuracy: 0.8143 - loss: 0.4214 - val_binary_accuracy: 0.5707 - val_loss: 0.9762 - learning_rate: 0.0010
# Epoch 7/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.8357 - loss: 0.4145 - val_binary_accuracy: 0.5870 - val_loss: 0.7957 - learning_rate: 0.0010
# Epoch 8/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.8571 - loss: 0.3234 - val_binary_accuracy: 0.5380 - val_loss: 1.3371 - learning_rate: 0.0010
# Epoch 9/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - binary_accuracy: 0.8728 - loss: 0.2940 - val_binary_accuracy: 0.5815 - val_loss: 0.8478 - learning_rate: 0.0010
# Epoch 10/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - binary_accuracy: 0.8871 - loss: 0.2804 - val_binary_accuracy: 0.5978 - val_loss: 0.7196 - learning_rate: 0.0010
# Epoch 11/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - binary_accuracy: 0.9110 - loss: 0.2188 - val_binary_accuracy: 0.5543 - val_loss: 1.4397 - learning_rate: 0.0010
# Epoch 12/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.8813 - loss: 0.2977 - val_binary_accuracy: 0.6196 - val_loss: 1.0165 - learning_rate: 0.0010
# Epoch 13/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - binary_accuracy: 0.9012 - loss: 0.2700 - val_binary_accuracy: 0.5707 - val_loss: 1.5258 - learning_rate: 0.0010
# Epoch 14/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - binary_accuracy: 0.8736 - loss: 0.2899 - val_binary_accuracy: 0.5924 - val_loss: 1.5789 - learning_rate: 0.0010
# Epoch 15/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.8945 - loss: 0.2562 - val_binary_accuracy: 0.5707 - val_loss: 1.8551 - learning_rate: 0.0010
# Epoch 16/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9216 - loss: 0.2106 - val_binary_accuracy: 0.5707 - val_loss: 1.8169 - learning_rate: 0.0010
# Epoch 17/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - binary_accuracy: 0.9637 - loss: 0.1079 - val_binary_accuracy: 0.5652 - val_loss: 1.9058 - learning_rate: 0.0010
# Epoch 18/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - binary_accuracy: 0.9541 - loss: 0.1043 - val_binary_accuracy: 0.5707 - val_loss: 2.7997 - learning_rate: 0.0010
# Epoch 19/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - binary_accuracy: 0.9590 - loss: 0.1093 - val_binary_accuracy: 0.5543 - val_loss: 2.4616 - learning_rate: 0.0010
# Epoch 20/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - binary_accuracy: 0.9609 - loss: 0.0836 - val_binary_accuracy: 0.5380 - val_loss: 3.8939 - learning_rate: 0.0010
# Epoch 21/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9599 - loss: 0.1068 - val_binary_accuracy: 0.6033 - val_loss: 1.4689 - learning_rate: 0.0010
# Epoch 22/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - binary_accuracy: 0.9546 - loss: 0.1076 - val_binary_accuracy: 0.5870 - val_loss: 2.6271 - learning_rate: 0.0010
# Epoch 23/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9699 - loss: 0.0834
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9696 - loss: 0.0833 - val_binary_accuracy: 0.6087 - val_loss: 2.1250 - learning_rate: 0.0010
# Epoch 24/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - binary_accuracy: 0.9707 - loss: 0.0954 - val_binary_accuracy: 0.5978 - val_loss: 2.3895 - learning_rate: 2.0000e-04
# Epoch 25/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - binary_accuracy: 0.9766 - loss: 0.0704 - val_binary_accuracy: 0.5924 - val_loss: 2.8265 - learning_rate: 2.0000e-04
# Epoch 26/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - binary_accuracy: 0.9936 - loss: 0.0288 - val_binary_accuracy: 0.6033 - val_loss: 2.5913 - learning_rate: 2.0000e-04
# Epoch 27/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9917 - loss: 0.0271 - val_binary_accuracy: 0.6033 - val_loss: 2.3459 - learning_rate: 2.0000e-04
# Epoch 28/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - binary_accuracy: 0.9911 - loss: 0.0279 - val_binary_accuracy: 0.6087 - val_loss: 2.2999 - learning_rate: 2.0000e-04
# Epoch 29/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9891 - loss: 0.0338 - val_binary_accuracy: 0.6196 - val_loss: 2.1997 - learning_rate: 2.0000e-04
# Epoch 30/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - binary_accuracy: 0.9872 - loss: 0.0298 - val_binary_accuracy: 0.6087 - val_loss: 2.4233 - learning_rate: 2.0000e-04
# Epoch 31/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9967 - loss: 0.0158 - val_binary_accuracy: 0.6033 - val_loss: 2.4818 - learning_rate: 2.0000e-04
# Epoch 32/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9912 - loss: 0.0182 - val_binary_accuracy: 0.6359 - val_loss: 2.2858 - learning_rate: 2.0000e-04
# Epoch 33/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9926 - loss: 0.0199 - val_binary_accuracy: 0.6359 - val_loss: 2.2264 - learning_rate: 2.0000e-04
# Epoch 34/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - binary_accuracy: 0.9889 - loss: 0.0232 - val_binary_accuracy: 0.6359 - val_loss: 2.1431 - learning_rate: 2.0000e-04
# Epoch 35/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9886 - loss: 0.0231 - val_binary_accuracy: 0.6467 - val_loss: 2.0594 - learning_rate: 2.0000e-04
# Epoch 36/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9916 - loss: 0.0172 - val_binary_accuracy: 0.6902 - val_loss: 1.7814 - learning_rate: 2.0000e-04
# Epoch 37/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9788 - loss: 0.0301 - val_binary_accuracy: 0.7120 - val_loss: 1.5376 - learning_rate: 2.0000e-04
# Epoch 38/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9973 - loss: 0.0118 - val_binary_accuracy: 0.7065 - val_loss: 1.5633 - learning_rate: 2.0000e-04
# Epoch 39/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9911 - loss: 0.0169 - val_binary_accuracy: 0.6793 - val_loss: 1.7564 - learning_rate: 2.0000e-04
# Epoch 40/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9842 - loss: 0.0277 - val_binary_accuracy: 0.7120 - val_loss: 1.5026 - learning_rate: 2.0000e-04
# Epoch 41/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - binary_accuracy: 0.9938 - loss: 0.0154 - val_binary_accuracy: 0.7391 - val_loss: 1.3386 - learning_rate: 2.0000e-04
# Epoch 42/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - binary_accuracy: 0.9951 - loss: 0.0127 - val_binary_accuracy: 0.7554 - val_loss: 1.3418 - learning_rate: 2.0000e-04
# Epoch 43/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - binary_accuracy: 0.9899 - loss: 0.0203 - val_binary_accuracy: 0.7554 - val_loss: 1.3748 - learning_rate: 2.0000e-04
# Epoch 44/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9934 - loss: 0.0219 - val_binary_accuracy: 0.7446 - val_loss: 1.3326 - learning_rate: 2.0000e-04
# Epoch 45/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9861 - loss: 0.0280 - val_binary_accuracy: 0.7446 - val_loss: 1.3213 - learning_rate: 2.0000e-04
# Epoch 46/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - binary_accuracy: 0.9900 - loss: 0.0226 - val_binary_accuracy: 0.7446 - val_loss: 1.3478 - learning_rate: 2.0000e-04
# Epoch 47/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - binary_accuracy: 0.9861 - loss: 0.0296 - val_binary_accuracy: 0.7391 - val_loss: 1.3171 - learning_rate: 2.0000e-04
# Epoch 48/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9922 - loss: 0.0178 - val_binary_accuracy: 0.7283 - val_loss: 1.2756 - learning_rate: 2.0000e-04
# Epoch 49/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9916 - loss: 0.0212 - val_binary_accuracy: 0.7337 - val_loss: 1.3000 - learning_rate: 2.0000e-04
# Epoch 50/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - binary_accuracy: 0.9828 - loss: 0.0332 - val_binary_accuracy: 0.7391 - val_loss: 1.2834 - learning_rate: 2.0000e-04
# Epoch 51/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - binary_accuracy: 0.9912 - loss: 0.0149 - val_binary_accuracy: 0.7337 - val_loss: 1.2960 - learning_rate: 2.0000e-04
# Epoch 52/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - binary_accuracy: 0.9905 - loss: 0.0180 - val_binary_accuracy: 0.7174 - val_loss: 1.3647 - learning_rate: 2.0000e-04
# Epoch 53/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9910 - loss: 0.0151 - val_binary_accuracy: 0.7228 - val_loss: 1.4010 - learning_rate: 2.0000e-04
# Epoch 54/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9940 - loss: 0.0099 - val_binary_accuracy: 0.7446 - val_loss: 1.3421 - learning_rate: 2.0000e-04
# Epoch 55/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9921 - loss: 0.0170 - val_binary_accuracy: 0.7500 - val_loss: 1.3156 - learning_rate: 2.0000e-04
# Epoch 56/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9887 - loss: 0.0231 - val_binary_accuracy: 0.7609 - val_loss: 1.2739 - learning_rate: 2.0000e-04
# Epoch 57/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - binary_accuracy: 0.9911 - loss: 0.0126 - val_binary_accuracy: 0.7717 - val_loss: 1.2697 - learning_rate: 2.0000e-04
# Epoch 58/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9910 - loss: 0.0168 - val_binary_accuracy: 0.7609 - val_loss: 1.3319 - learning_rate: 2.0000e-04
# Epoch 59/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - binary_accuracy: 0.9899 - loss: 0.0169 - val_binary_accuracy: 0.7446 - val_loss: 1.3927 - learning_rate: 2.0000e-04
# Epoch 60/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - binary_accuracy: 0.9943 - loss: 0.0167 - val_binary_accuracy: 0.7663 - val_loss: 1.3763 - learning_rate: 2.0000e-04
# Epoch 61/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - binary_accuracy: 0.9877 - loss: 0.0207 - val_binary_accuracy: 0.7663 - val_loss: 1.3625 - learning_rate: 2.0000e-04
# Epoch 62/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9839 - loss: 0.0287 - val_binary_accuracy: 0.7446 - val_loss: 1.5100 - learning_rate: 2.0000e-04
# Epoch 63/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - binary_accuracy: 0.9931 - loss: 0.0200 - val_binary_accuracy: 0.7609 - val_loss: 1.5254 - learning_rate: 2.0000e-04
# Epoch 64/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - binary_accuracy: 0.9936 - loss: 0.0196 - val_binary_accuracy: 0.7717 - val_loss: 1.5133 - learning_rate: 2.0000e-04
# Epoch 65/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9870 - loss: 0.0226 - val_binary_accuracy: 0.7772 - val_loss: 1.4966 - learning_rate: 2.0000e-04
# Epoch 66/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9903 - loss: 0.0146 - val_binary_accuracy: 0.7826 - val_loss: 1.4400 - learning_rate: 2.0000e-04
# Epoch 67/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9898 - loss: 0.0146 - val_binary_accuracy: 0.7772 - val_loss: 1.4397 - learning_rate: 2.0000e-04
# Epoch 68/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - binary_accuracy: 0.9967 - loss: 0.0121 - val_binary_accuracy: 0.7772 - val_loss: 1.4302 - learning_rate: 2.0000e-04
# Epoch 69/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - binary_accuracy: 0.9914 - loss: 0.0157 - val_binary_accuracy: 0.7717 - val_loss: 1.4243 - learning_rate: 2.0000e-04
# Epoch 70/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - binary_accuracy: 0.9892 - loss: 0.0150 - val_binary_accuracy: 0.7826 - val_loss: 1.4400 - learning_rate: 2.0000e-04
# Epoch 71/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9885 - loss: 0.0184 - val_binary_accuracy: 0.7772 - val_loss: 1.5050 - learning_rate: 2.0000e-04
# Epoch 72/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9877 - loss: 0.0186 - val_binary_accuracy: 0.7609 - val_loss: 1.4950 - learning_rate: 2.0000e-04
# Epoch 73/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - binary_accuracy: 0.9932 - loss: 0.0159 - val_binary_accuracy: 0.7609 - val_loss: 1.5260 - learning_rate: 2.0000e-04
# Epoch 74/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - binary_accuracy: 0.9918 - loss: 0.0168 - val_binary_accuracy: 0.7772 - val_loss: 1.5274 - learning_rate: 2.0000e-04
# Epoch 75/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - binary_accuracy: 0.9912 - loss: 0.0124 - val_binary_accuracy: 0.7772 - val_loss: 1.5206 - learning_rate: 2.0000e-04
# Epoch 76/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9943 - loss: 0.0152 - val_binary_accuracy: 0.7663 - val_loss: 1.5340 - learning_rate: 2.0000e-04
# Epoch 77/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9935 - loss: 0.0224 - val_binary_accuracy: 0.7717 - val_loss: 1.5198 - learning_rate: 2.0000e-04
# Epoch 78/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9940 - loss: 0.0102 - val_binary_accuracy: 0.7826 - val_loss: 1.4927 - learning_rate: 2.0000e-04
# Epoch 79/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9906 - loss: 0.0192 - val_binary_accuracy: 0.7772 - val_loss: 1.4874 - learning_rate: 2.0000e-04
# Epoch 80/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9906 - loss: 0.0177 - val_binary_accuracy: 0.7663 - val_loss: 1.5163 - learning_rate: 2.0000e-04
# Epoch 81/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9864 - loss: 0.0199 - val_binary_accuracy: 0.7663 - val_loss: 1.5122 - learning_rate: 2.0000e-04
# Epoch 82/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9883 - loss: 0.0247 - val_binary_accuracy: 0.7826 - val_loss: 1.4541 - learning_rate: 2.0000e-04
# Epoch 83/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9940 - loss: 0.0157 - val_binary_accuracy: 0.7717 - val_loss: 1.4624 - learning_rate: 2.0000e-04
# Epoch 84/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9932 - loss: 0.0125 - val_binary_accuracy: 0.7609 - val_loss: 1.5109 - learning_rate: 2.0000e-04
# Epoch 85/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9965 - loss: 0.0098 - val_binary_accuracy: 0.7717 - val_loss: 1.4930 - learning_rate: 2.0000e-04
# Epoch 86/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9902 - loss: 0.0131
# Epoch 86: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9899 - loss: 0.0136 - val_binary_accuracy: 0.7609 - val_loss: 1.5373 - learning_rate: 2.0000e-04
# Epoch 87/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - binary_accuracy: 0.9959 - loss: 0.0110 - val_binary_accuracy: 0.7554 - val_loss: 1.5537 - learning_rate: 4.0000e-05
# Epoch 88/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - binary_accuracy: 0.9881 - loss: 0.0232 - val_binary_accuracy: 0.7554 - val_loss: 1.5610 - learning_rate: 4.0000e-05
# Epoch 89/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - binary_accuracy: 0.9887 - loss: 0.0267 - val_binary_accuracy: 0.7609 - val_loss: 1.5540 - learning_rate: 4.0000e-05
# Epoch 90/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - binary_accuracy: 0.9915 - loss: 0.0127 - val_binary_accuracy: 0.7609 - val_loss: 1.5469 - learning_rate: 4.0000e-05
# Epoch 91/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9919 - loss: 0.0166 - val_binary_accuracy: 0.7609 - val_loss: 1.5351 - learning_rate: 4.0000e-05
# Epoch 92/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - binary_accuracy: 0.9869 - loss: 0.0198 - val_binary_accuracy: 0.7663 - val_loss: 1.5286 - learning_rate: 4.0000e-05
# Epoch 93/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9935 - loss: 0.0148 - val_binary_accuracy: 0.7717 - val_loss: 1.5351 - learning_rate: 4.0000e-05
# Epoch 94/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - binary_accuracy: 0.9904 - loss: 0.0186 - val_binary_accuracy: 0.7717 - val_loss: 1.5415 - learning_rate: 4.0000e-05
# Epoch 95/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9890 - loss: 0.0186 - val_binary_accuracy: 0.7663 - val_loss: 1.5646 - learning_rate: 4.0000e-05
# Epoch 96/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - binary_accuracy: 0.9921 - loss: 0.0122 - val_binary_accuracy: 0.7609 - val_loss: 1.5714 - learning_rate: 4.0000e-05
# Epoch 97/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - binary_accuracy: 0.9891 - loss: 0.0168 - val_binary_accuracy: 0.7609 - val_loss: 1.5450 - learning_rate: 4.0000e-05
# Epoch 98/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - binary_accuracy: 0.9856 - loss: 0.0218 - val_binary_accuracy: 0.7663 - val_loss: 1.4817 - learning_rate: 4.0000e-05
# Epoch 99/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9954 - loss: 0.0109 - val_binary_accuracy: 0.7663 - val_loss: 1.4615 - learning_rate: 4.0000e-05
# Epoch 100/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9965 - loss: 0.0141 - val_binary_accuracy: 0.7772 - val_loss: 1.4548 - learning_rate: 4.0000e-05
# Epoch 101/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - binary_accuracy: 0.9922 - loss: 0.0138 - val_binary_accuracy: 0.7772 - val_loss: 1.4603 - learning_rate: 4.0000e-05
# Epoch 102/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9934 - loss: 0.0130 - val_binary_accuracy: 0.7772 - val_loss: 1.4678 - learning_rate: 4.0000e-05
# Epoch 103/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9958 - loss: 0.0102 - val_binary_accuracy: 0.7772 - val_loss: 1.4780 - learning_rate: 4.0000e-05
# Epoch 104/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9894 - loss: 0.0214 - val_binary_accuracy: 0.7717 - val_loss: 1.4872 - learning_rate: 4.0000e-05
# Epoch 105/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - binary_accuracy: 0.9933 - loss: 0.0159 - val_binary_accuracy: 0.7717 - val_loss: 1.4982 - learning_rate: 4.0000e-05
# Epoch 106/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9963 - loss: 0.0104
# Epoch 106: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - binary_accuracy: 0.9962 - loss: 0.0104 - val_binary_accuracy: 0.7717 - val_loss: 1.5073 - learning_rate: 4.0000e-05
# Epoch 106: early stopping
# Restoring model weights from the end of the best epoch: 66.

# %% [markdown]
# # Resultados

# %%
y_pred = model.predict(X_test, batch_size=batch_size, verbose=1)
y_pred_bool = (y_pred > 0.5).astype(int)

y_test = np.concatenate([y for x, y in test_base], axis=0)

print(classification_report(y_test, y_pred_bool))
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 275ms/step
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.78      0.78        91
#          1.0       0.78      0.78      0.78        93
#
#     accuracy                           0.78       184
#    macro avg       0.78      0.78      0.78       184
# weighted avg       0.78      0.78      0.78       184

# %%
history_frame = pd.DataFrame(history.history)
history_frame.loc[:, ["loss", "val_loss"]].plot()
history_frame.loc[:, ["binary_accuracy", "val_binary_accuracy"]].plot()
# Out:
# <Axes: >
