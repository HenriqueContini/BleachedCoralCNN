# %%
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
import numpy as np

from sklearn.metrics import classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Dense,
    Flatten,
    Conv2D,
    MaxPooling2D,
    Dropout,
    BatchNormalization,
    Input,
    RandomFlip,
    RandomBrightness,
    RandomContrast,
    Rescaling,
    RandomRotation,
    RandomZoom
)
from tensorflow.keras.metrics import BinaryAccuracy
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %%
seed = 1000
batch_size = 64
img_size=224

# %%
plt.rc("figure", autolayout=True)
plt.rc(
    "axes",
    labelweight="bold",
    labelsize="large",
    titleweight="bold",
    titlesize=18,
    titlepad=10,
)
plt.rc("image", cmap="magma")

# %% [markdown]
# # Dataset
#
# A princípio, os dados serão separados apenas em treinamento e teste

# %%
X_train, X_test = image_dataset_from_directory(
    directory="./dataset",
    labels="inferred",
    label_mode="binary",
    color_mode="rgb",
    image_size=(img_size, img_size),
    batch_size=batch_size,
    shuffle=True,
    seed=seed,
    validation_split=0.2,
    subset="both",
    pad_to_aspect_ratio=False,
    verbose=True,
)
# Out:
# Found 923 files belonging to 2 classes.
# Using 739 files for training.
# Using 184 files for validation.

# %% [markdown]
# # Modelo

# %%
data_augmentation = Sequential([
	RandomFlip(mode="horizontal", seed=seed),
	RandomBrightness(factor=0.2, seed=seed),
	RandomContrast(factor=0.2, seed=seed)
])

# %%
for images, labels in X_train.take(1):
    # Aplique o data augmentation
    augmented_images = data_augmentation(images)

    # Plote as imagens originais e aumentadas lado a lado
    plt.figure(figsize=(12, 6))
    for i in range(6):  # Mostra as 6 primeiras imagens do batch
        # Original
        plt.subplot(2, 6, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title("Original")
        plt.axis("off")
        
        # Augmentada
        plt.subplot(2, 6, i + 7)
        plt.imshow(augmented_images[i].numpy().astype("uint8"))
        plt.title("Augmentada")
        plt.axis("off")
    plt.tight_layout()
    plt.show()
    break  # Mostra só o primeiro batch

# %%
model = Sequential([
    Input(shape=(img_size, img_size, 3)),
	data_augmentation,
 	Rescaling(1./255),
    Conv2D(filters=32, kernel_size=(3, 3), activation="relu", kernel_initializer="he_normal", padding="same"),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(filters=32, kernel_size=(3, 3), activation="relu", kernel_initializer="he_normal", padding="same"),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(filters=64, kernel_size=(3, 3), activation="relu", kernel_initializer="he_normal", padding="same"),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(filters=128, kernel_size=(3, 3), activation="relu", kernel_initializer="he_normal", padding="same"),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Flatten(),
    Dense(units=1024, activation="relu", kernel_initializer="he_normal"),
    Dropout(0.2),
    Dense(units=512, activation="relu", kernel_initializer="he_normal"),
    Dropout(0.2),
    Dense(units=128, activation="relu", kernel_initializer="he_normal"),
    Dense(units=1, activation="sigmoid")
])

model.compile(
    optimizer="adam", loss="binary_crossentropy", metrics=[BinaryAccuracy()]
)

model.summary()
# Out:
# Model: "sequential_25"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential_24 (Sequential)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling_7 (Rescaling)         │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 112, 112, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 112, 112, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 56, 56, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 56, 56, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 56, 56, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 28, 28, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 28, 28, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 28, 28, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 14, 14, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1024)           │    25,691,136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 128)            │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 26,385,249 (100.65 MB)
#  Trainable params: 26,384,737 (100.65 MB)
#  Non-trainable params: 512 (2.00 KB)

# %% [markdown]
# CallBacks

# %%
es = EarlyStopping(
    monitor="val_binary_accuracy", patience=40, restore_best_weights=True, verbose=1
)

rlr = ReduceLROnPlateau(monitor="val_binary_accuracy", factor=0.2, patience=20, verbose=True)

# %%
history = model.fit(
    X_train,
    validation_data=X_test,
    epochs=200,
    callbacks=[es, rlr],
)
# Out:
# Epoch 1/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - binary_accuracy: 0.5345 - loss: 6.9173 - val_binary_accuracy: 0.4946 - val_loss: 7.3943 - learning_rate: 0.0010
# Epoch 2/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.6591 - loss: 1.4314 - val_binary_accuracy: 0.6739 - val_loss: 0.8242 - learning_rate: 0.0010
# Epoch 3/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.7034 - loss: 1.2302 - val_binary_accuracy: 0.4946 - val_loss: 6.7687 - learning_rate: 0.0010
# Epoch 4/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.7113 - loss: 1.0552 - val_binary_accuracy: 0.5217 - val_loss: 3.2252 - learning_rate: 0.0010
# Epoch 5/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.7096 - loss: 0.8724 - val_binary_accuracy: 0.5652 - val_loss: 1.3516 - learning_rate: 0.0010
# Epoch 6/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.7739 - loss: 0.6174 - val_binary_accuracy: 0.5109 - val_loss: 1.6177 - learning_rate: 0.0010
# Epoch 7/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.7401 - loss: 0.7775 - val_binary_accuracy: 0.6033 - val_loss: 0.9418 - learning_rate: 0.0010
# Epoch 8/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.7515 - loss: 0.6787 - val_binary_accuracy: 0.6141 - val_loss: 0.7347 - learning_rate: 0.0010
# Epoch 9/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.7905 - loss: 0.5564 - val_binary_accuracy: 0.6739 - val_loss: 0.6231 - learning_rate: 0.0010
# Epoch 10/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - binary_accuracy: 0.7663 - loss: 0.4790 - val_binary_accuracy: 0.6522 - val_loss: 0.6147 - learning_rate: 0.0010
# Epoch 11/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.7919 - loss: 0.4890 - val_binary_accuracy: 0.6685 - val_loss: 0.6039 - learning_rate: 0.0010
# Epoch 12/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.8009 - loss: 0.4959 - val_binary_accuracy: 0.6467 - val_loss: 0.6042 - learning_rate: 0.0010
# Epoch 13/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.7834 - loss: 0.4673 - val_binary_accuracy: 0.6793 - val_loss: 0.6767 - learning_rate: 0.0010
# Epoch 14/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.8193 - loss: 0.4017 - val_binary_accuracy: 0.6739 - val_loss: 0.6830 - learning_rate: 0.0010
# Epoch 15/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.8210 - loss: 0.4019 - val_binary_accuracy: 0.6359 - val_loss: 0.6215 - learning_rate: 0.0010
# Epoch 16/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.8471 - loss: 0.3420 - val_binary_accuracy: 0.7065 - val_loss: 0.6685 - learning_rate: 0.0010
# Epoch 17/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.8645 - loss: 0.3471 - val_binary_accuracy: 0.7120 - val_loss: 0.5356 - learning_rate: 0.0010
# Epoch 18/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.8572 - loss: 0.3123 - val_binary_accuracy: 0.6902 - val_loss: 0.6954 - learning_rate: 0.0010
# Epoch 19/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.8689 - loss: 0.2879 - val_binary_accuracy: 0.6848 - val_loss: 0.7360 - learning_rate: 0.0010
# Epoch 20/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.8755 - loss: 0.2905 - val_binary_accuracy: 0.7120 - val_loss: 0.6192 - learning_rate: 0.0010
# Epoch 21/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.8687 - loss: 0.2683 - val_binary_accuracy: 0.7065 - val_loss: 0.7437 - learning_rate: 0.0010
# Epoch 22/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.8867 - loss: 0.2851 - val_binary_accuracy: 0.7120 - val_loss: 0.6450 - learning_rate: 0.0010
# Epoch 23/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.8864 - loss: 0.2919 - val_binary_accuracy: 0.6685 - val_loss: 0.9630 - learning_rate: 0.0010
# Epoch 24/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9182 - loss: 0.2230 - val_binary_accuracy: 0.7065 - val_loss: 0.8424 - learning_rate: 0.0010
# Epoch 25/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9275 - loss: 0.2053 - val_binary_accuracy: 0.7283 - val_loss: 0.6855 - learning_rate: 0.0010
# Epoch 26/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - binary_accuracy: 0.9143 - loss: 0.2037 - val_binary_accuracy: 0.7391 - val_loss: 0.6609 - learning_rate: 0.0010
# Epoch 27/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - binary_accuracy: 0.9151 - loss: 0.2327 - val_binary_accuracy: 0.7663 - val_loss: 0.6942 - learning_rate: 0.0010
# Epoch 28/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9071 - loss: 0.2771 - val_binary_accuracy: 0.7337 - val_loss: 0.7190 - learning_rate: 0.0010
# Epoch 29/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9306 - loss: 0.1672 - val_binary_accuracy: 0.7446 - val_loss: 0.5858 - learning_rate: 0.0010
# Epoch 30/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9584 - loss: 0.1276 - val_binary_accuracy: 0.7500 - val_loss: 0.8735 - learning_rate: 0.0010
# Epoch 31/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9325 - loss: 0.1608 - val_binary_accuracy: 0.7337 - val_loss: 0.8179 - learning_rate: 0.0010
# Epoch 32/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9315 - loss: 0.1799 - val_binary_accuracy: 0.7500 - val_loss: 0.7181 - learning_rate: 0.0010
# Epoch 33/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9485 - loss: 0.1314 - val_binary_accuracy: 0.7717 - val_loss: 0.7393 - learning_rate: 0.0010
# Epoch 34/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9442 - loss: 0.1330 - val_binary_accuracy: 0.7446 - val_loss: 0.8465 - learning_rate: 0.0010
# Epoch 35/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9454 - loss: 0.1373 - val_binary_accuracy: 0.7717 - val_loss: 0.6752 - learning_rate: 0.0010
# Epoch 36/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9514 - loss: 0.1421 - val_binary_accuracy: 0.7554 - val_loss: 0.9812 - learning_rate: 0.0010
# Epoch 37/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9446 - loss: 0.1267 - val_binary_accuracy: 0.7554 - val_loss: 0.8345 - learning_rate: 0.0010
# Epoch 38/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9603 - loss: 0.0970 - val_binary_accuracy: 0.7880 - val_loss: 0.8623 - learning_rate: 0.0010
# Epoch 39/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9797 - loss: 0.0910 - val_binary_accuracy: 0.7609 - val_loss: 0.7643 - learning_rate: 0.0010
# Epoch 40/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9627 - loss: 0.1138 - val_binary_accuracy: 0.6957 - val_loss: 1.1305 - learning_rate: 0.0010
# Epoch 41/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9469 - loss: 0.1345 - val_binary_accuracy: 0.6902 - val_loss: 0.9838 - learning_rate: 0.0010
# Epoch 42/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9748 - loss: 0.0753 - val_binary_accuracy: 0.7772 - val_loss: 0.8664 - learning_rate: 0.0010
# Epoch 43/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9578 - loss: 0.1199 - val_binary_accuracy: 0.7446 - val_loss: 0.9621 - learning_rate: 0.0010
# Epoch 44/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9672 - loss: 0.0905 - val_binary_accuracy: 0.7554 - val_loss: 0.7892 - learning_rate: 0.0010
# Epoch 45/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9782 - loss: 0.0541 - val_binary_accuracy: 0.7717 - val_loss: 0.9567 - learning_rate: 0.0010
# Epoch 46/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9808 - loss: 0.0635 - val_binary_accuracy: 0.7554 - val_loss: 0.9578 - learning_rate: 0.0010
# Epoch 47/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9754 - loss: 0.0506 - val_binary_accuracy: 0.7446 - val_loss: 0.9936 - learning_rate: 0.0010
# Epoch 48/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9947 - loss: 0.0311 - val_binary_accuracy: 0.7500 - val_loss: 1.1352 - learning_rate: 0.0010
# Epoch 49/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9878 - loss: 0.0324 - val_binary_accuracy: 0.7554 - val_loss: 1.0595 - learning_rate: 0.0010
# Epoch 50/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9914 - loss: 0.0371 - val_binary_accuracy: 0.7554 - val_loss: 1.0369 - learning_rate: 0.0010
# Epoch 51/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9804 - loss: 0.0527 - val_binary_accuracy: 0.7228 - val_loss: 1.2950 - learning_rate: 0.0010
# Epoch 52/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9749 - loss: 0.0532 - val_binary_accuracy: 0.7663 - val_loss: 1.4548 - learning_rate: 0.0010
# Epoch 53/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9751 - loss: 0.0744 - val_binary_accuracy: 0.7283 - val_loss: 1.3780 - learning_rate: 0.0010
# Epoch 54/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9717 - loss: 0.0857 - val_binary_accuracy: 0.7609 - val_loss: 1.0891 - learning_rate: 0.0010
# Epoch 55/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9808 - loss: 0.0624 - val_binary_accuracy: 0.7500 - val_loss: 1.1169 - learning_rate: 0.0010
# Epoch 56/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9809 - loss: 0.0504 - val_binary_accuracy: 0.7717 - val_loss: 1.1347 - learning_rate: 0.0010
# Epoch 57/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9739 - loss: 0.0807 - val_binary_accuracy: 0.7500 - val_loss: 1.1960 - learning_rate: 0.0010
# Epoch 58/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9770 - loss: 0.0661
# Epoch 58: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9769 - loss: 0.0674 - val_binary_accuracy: 0.7446 - val_loss: 1.2193 - learning_rate: 0.0010
# Epoch 59/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9550 - loss: 0.1194 - val_binary_accuracy: 0.7446 - val_loss: 1.2610 - learning_rate: 2.0000e-04
# Epoch 60/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9767 - loss: 0.0753 - val_binary_accuracy: 0.7717 - val_loss: 1.2443 - learning_rate: 2.0000e-04
# Epoch 61/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9898 - loss: 0.0379 - val_binary_accuracy: 0.7717 - val_loss: 1.2028 - learning_rate: 2.0000e-04
# Epoch 62/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9905 - loss: 0.0332 - val_binary_accuracy: 0.7554 - val_loss: 1.2166 - learning_rate: 2.0000e-04
# Epoch 63/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9863 - loss: 0.0355 - val_binary_accuracy: 0.7663 - val_loss: 1.1929 - learning_rate: 2.0000e-04
# Epoch 64/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9930 - loss: 0.0223 - val_binary_accuracy: 0.7663 - val_loss: 1.2057 - learning_rate: 2.0000e-04
# Epoch 65/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9839 - loss: 0.0404 - val_binary_accuracy: 0.7663 - val_loss: 1.2125 - learning_rate: 2.0000e-04
# Epoch 66/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9950 - loss: 0.0223 - val_binary_accuracy: 0.7772 - val_loss: 1.2157 - learning_rate: 2.0000e-04
# Epoch 67/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9836 - loss: 0.0331 - val_binary_accuracy: 0.7826 - val_loss: 1.2222 - learning_rate: 2.0000e-04
# Epoch 68/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9813 - loss: 0.0371 - val_binary_accuracy: 0.7826 - val_loss: 1.2293 - learning_rate: 2.0000e-04
# Epoch 69/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9784 - loss: 0.0470 - val_binary_accuracy: 0.7717 - val_loss: 1.1573 - learning_rate: 2.0000e-04
# Epoch 70/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9965 - loss: 0.0141 - val_binary_accuracy: 0.7609 - val_loss: 1.1672 - learning_rate: 2.0000e-04
# Epoch 71/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9824 - loss: 0.0282 - val_binary_accuracy: 0.7772 - val_loss: 1.1774 - learning_rate: 2.0000e-04
# Epoch 72/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - binary_accuracy: 0.9882 - loss: 0.0293 - val_binary_accuracy: 0.7772 - val_loss: 1.1878 - learning_rate: 2.0000e-04
# Epoch 73/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - binary_accuracy: 0.9949 - loss: 0.0144 - val_binary_accuracy: 0.7663 - val_loss: 1.2211 - learning_rate: 2.0000e-04
# Epoch 74/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - binary_accuracy: 0.9961 - loss: 0.0142 - val_binary_accuracy: 0.7717 - val_loss: 1.2508 - learning_rate: 2.0000e-04
# Epoch 75/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - binary_accuracy: 0.9879 - loss: 0.0210 - val_binary_accuracy: 0.7663 - val_loss: 1.2063 - learning_rate: 2.0000e-04
# Epoch 76/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - binary_accuracy: 0.9940 - loss: 0.0179 - val_binary_accuracy: 0.7717 - val_loss: 1.2078 - learning_rate: 2.0000e-04
# Epoch 77/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - binary_accuracy: 0.9934 - loss: 0.0205 - val_binary_accuracy: 0.7663 - val_loss: 1.1959 - learning_rate: 2.0000e-04
# Epoch 78/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9921 - loss: 0.0196
# Epoch 78: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - binary_accuracy: 0.9919 - loss: 0.0195 - val_binary_accuracy: 0.7717 - val_loss: 1.1868 - learning_rate: 2.0000e-04
# Epoch 78: early stopping
# Restoring model weights from the end of the best epoch: 38.

# %% [markdown]
# # Resultados

# %%
y_pred = model.predict(X_test, batch_size=batch_size, verbose=1)
y_pred_bool = (y_pred > 0.5).astype(int)

y_test = np.concatenate([y for x, y in X_test], axis=0)

print(classification_report(y_test, y_pred_bool))
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 244ms/step
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.85      0.80        91
#          1.0       0.83      0.73      0.78        93
#
#     accuracy                           0.79       184
#    macro avg       0.79      0.79      0.79       184
# weighted avg       0.79      0.79      0.79       184

# %%
history_frame = pd.DataFrame(history.history)
history_frame.loc[:, ["loss", "val_loss"]].plot()
history_frame.loc[:, ["binary_accuracy", "val_binary_accuracy"]].plot()
# Out:
# <Axes: >
