# %%
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
import numpy as np

from sklearn.metrics import classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Dense,
    Flatten,
    Conv2D,
    MaxPooling2D,
    Dropout,
    BatchNormalization,
    Input,
    RandomFlip,
    RandomBrightness,
    RandomContrast,
    Rescaling,
    RandomRotation
)
from tensorflow.keras.metrics import BinaryAccuracy
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %%
seed = 1000
batch_size = 32
img_size=224

# %%
plt.rc("figure", autolayout=True)
plt.rc(
    "axes",
    labelweight="bold",
    labelsize="large",
    titleweight="bold",
    titlesize=18,
    titlepad=10,
)
plt.rc("image", cmap="magma")

# %% [markdown]
# # Dataset
#
# A princípio, os dados serão separados apenas em treinamento e teste

# %%
X_train, X_test = image_dataset_from_directory(
    directory="./dataset",
    labels="inferred",
    label_mode="binary",
    color_mode="rgb",
    image_size=(img_size, img_size),
    batch_size=batch_size,
    shuffle=True,
    seed=seed,
    validation_split=0.2,
    subset="both",
    pad_to_aspect_ratio=False,
    verbose=True,
)
# Out:
# Found 923 files belonging to 2 classes.
# Using 739 files for training.
# Using 184 files for validation.

# %%
AUTOTUNE = tf.data.AUTOTUNE
X_train = X_train.cache().prefetch(buffer_size=AUTOTUNE)
X_test = X_test.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# # Modelo

# %%
data_augmentation = Sequential([
	RandomFlip(mode="horizontal", seed=seed),
	RandomBrightness(factor=0.2, seed=seed),
	RandomContrast(factor=0.2, seed=seed),
	RandomRotation(factor=0.2, seed=seed)
])

# %%
for images, labels in X_train.take(1):
    # Aplique o data augmentation
    augmented_images = data_augmentation(images)

    # Plote as imagens originais e aumentadas lado a lado
    plt.figure(figsize=(12, 6))
    for i in range(6):  # Mostra as 6 primeiras imagens do batch
        # Original
        plt.subplot(2, 6, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title("Original")
        plt.axis("off")
        
        # Augmentada
        plt.subplot(2, 6, i + 7)
        plt.imshow(augmented_images[i].numpy().astype("uint8"))
        plt.title("Augmentada")
        plt.axis("off")
    plt.tight_layout()
    plt.show()
    break  # Mostra só o primeiro batch

# %%
model = Sequential([
    Input(shape=(img_size, img_size, 3)),
	data_augmentation,
 	Rescaling(1./255),
    Conv2D(filters=32, kernel_size=(3, 3), activation="relu", kernel_initializer="he_normal", padding="same"),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(filters=64, kernel_size=(3, 3), activation="relu", kernel_initializer="he_normal", padding="same"),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(filters=256, kernel_size=(3, 3), activation="relu", kernel_initializer="he_normal", padding="same"),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(filters=512, kernel_size=(3, 3), activation="relu", kernel_initializer="he_normal", padding="same"),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(filters=512, kernel_size=(3, 3), activation="relu", kernel_initializer="he_normal", padding="same"),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Flatten(),
    Dense(units=512, activation="relu", kernel_initializer="he_normal"),
    Dropout(0.2),
    Dense(units=256, activation="relu", kernel_initializer="he_normal"),
    Dropout(0.2),
    Dense(units=128, activation="relu", kernel_initializer="he_normal"),
    Dense(units=1, activation="sigmoid")
])

model.compile(
    optimizer="adam", loss="binary_crossentropy", metrics=[BinaryAccuracy()]
)

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 56, 56, 256)    │       147,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 56, 56, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 28, 28, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │    12,845,568 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,722,497 (63.79 MB)
#  Trainable params: 16,719,745 (63.78 MB)
#  Non-trainable params: 2,752 (10.75 KB)

# %% [markdown]
# CallBacks

# %%
es = EarlyStopping(
    monitor="val_binary_accuracy", patience=40, restore_best_weights=True, verbose=1
)

rlr = ReduceLROnPlateau(monitor="val_binary_accuracy", factor=0.2, patience=30, verbose=True)

cp = ModelCheckpoint(
    "./checkpoint/cnn-7/checkpoint.model.keras",
    monitor="val_binary_accuracy",
    save_best_only=True,
    mode="max",
    verbose=1,
)

# %%
history = model.fit(
    X_train,
    validation_data=X_test,
    epochs=200,
    callbacks=[es, rlr, cp],
)
# Out:
# Epoch 1/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.6150 - loss: 2.8099
# Epoch 1: val_binary_accuracy improved from -inf to 0.51087, saving model to ./checkpoint/cnn-7/checkpoint.model.keras
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - binary_accuracy: 0.6161 - loss: 2.8028 - val_binary_accuracy: 0.5109 - val_loss: 2.0879 - learning_rate: 0.0010
# Epoch 2/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.5827 - loss: 2.6928
# Epoch 2: val_binary_accuracy improved from 0.51087 to 0.56522, saving model to ./checkpoint/cnn-7/checkpoint.model.keras
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - binary_accuracy: 0.5845 - loss: 2.6791 - val_binary_accuracy: 0.5652 - val_loss: 1.7988 - learning_rate: 0.0010
# Epoch 3/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.6210 - loss: 2.2224
# Epoch 3: val_binary_accuracy improved from 0.56522 to 0.68478, saving model to ./checkpoint/cnn-7/checkpoint.model.keras
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - binary_accuracy: 0.6218 - loss: 2.2162 - val_binary_accuracy: 0.6848 - val_loss: 1.0885 - learning_rate: 0.0010
# Epoch 4/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.6423 - loss: 1.9437
# Epoch 4: val_binary_accuracy did not improve from 0.68478
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.6435 - loss: 1.9317 - val_binary_accuracy: 0.6033 - val_loss: 1.2847 - learning_rate: 0.0010
# Epoch 5/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.6337 - loss: 1.9039
# Epoch 5: val_binary_accuracy did not improve from 0.68478
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.6344 - loss: 1.9034 - val_binary_accuracy: 0.6250 - val_loss: 1.0176 - learning_rate: 0.0010
# Epoch 6/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.6358 - loss: 1.9623
# Epoch 6: val_binary_accuracy improved from 0.68478 to 0.69022, saving model to ./checkpoint/cnn-7/checkpoint.model.keras
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - binary_accuracy: 0.6364 - loss: 1.9537 - val_binary_accuracy: 0.6902 - val_loss: 0.7875 - learning_rate: 0.0010
# Epoch 7/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.6430 - loss: 1.3929
# Epoch 7: val_binary_accuracy did not improve from 0.69022
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - binary_accuracy: 0.6442 - loss: 1.3899 - val_binary_accuracy: 0.5924 - val_loss: 1.0341 - learning_rate: 0.0010
# Epoch 8/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.6277 - loss: 1.2823
# Epoch 8: val_binary_accuracy did not improve from 0.69022
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - binary_accuracy: 0.6283 - loss: 1.2764 - val_binary_accuracy: 0.6087 - val_loss: 1.1574 - learning_rate: 0.0010
# Epoch 9/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.6772 - loss: 1.2891
# Epoch 9: val_binary_accuracy improved from 0.69022 to 0.70652, saving model to ./checkpoint/cnn-7/checkpoint.model.keras
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - binary_accuracy: 0.6774 - loss: 1.2848 - val_binary_accuracy: 0.7065 - val_loss: 1.0141 - learning_rate: 0.0010
# Epoch 10/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.6663 - loss: 1.0448
# Epoch 10: val_binary_accuracy did not improve from 0.70652
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.6671 - loss: 1.0447 - val_binary_accuracy: 0.6304 - val_loss: 1.0148 - learning_rate: 0.0010
# Epoch 11/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.6666 - loss: 1.0142
# Epoch 11: val_binary_accuracy did not improve from 0.70652
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.6679 - loss: 1.0143 - val_binary_accuracy: 0.6250 - val_loss: 0.9879 - learning_rate: 0.0010
# Epoch 12/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.6700 - loss: 1.0087
# Epoch 12: val_binary_accuracy did not improve from 0.70652
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.6706 - loss: 1.0090 - val_binary_accuracy: 0.6848 - val_loss: 0.7386 - learning_rate: 0.0010
# Epoch 13/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.6574 - loss: 1.0635
# Epoch 13: val_binary_accuracy did not improve from 0.70652
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.6580 - loss: 1.0619 - val_binary_accuracy: 0.6250 - val_loss: 1.2047 - learning_rate: 0.0010
# Epoch 14/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.7189 - loss: 0.9261
# Epoch 14: val_binary_accuracy did not improve from 0.70652
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.7187 - loss: 0.9267 - val_binary_accuracy: 0.6304 - val_loss: 1.0058 - learning_rate: 0.0010
# Epoch 15/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.6773 - loss: 1.0020
# Epoch 15: val_binary_accuracy did not improve from 0.70652
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.6772 - loss: 0.9989 - val_binary_accuracy: 0.6685 - val_loss: 0.7421 - learning_rate: 0.0010
# Epoch 16/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.6768 - loss: 0.7941
# Epoch 16: val_binary_accuracy did not improve from 0.70652
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.6778 - loss: 0.7929 - val_binary_accuracy: 0.6793 - val_loss: 0.7610 - learning_rate: 0.0010
# Epoch 17/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.6770 - loss: 1.0358
# Epoch 17: val_binary_accuracy did not improve from 0.70652
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.6781 - loss: 1.0317 - val_binary_accuracy: 0.6848 - val_loss: 0.7581 - learning_rate: 0.0010
# Epoch 18/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.6635 - loss: 0.9410
# Epoch 18: val_binary_accuracy did not improve from 0.70652
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.6642 - loss: 0.9369 - val_binary_accuracy: 0.6739 - val_loss: 0.7828 - learning_rate: 0.0010
# Epoch 19/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.7107 - loss: 0.8756
# Epoch 19: val_binary_accuracy did not improve from 0.70652
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.7109 - loss: 0.8719 - val_binary_accuracy: 0.6848 - val_loss: 0.6576 - learning_rate: 0.0010
# Epoch 20/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.7309 - loss: 0.6922
# Epoch 20: val_binary_accuracy did not improve from 0.70652
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.7314 - loss: 0.6949 - val_binary_accuracy: 0.6522 - val_loss: 0.8194 - learning_rate: 0.0010
# Epoch 21/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.7171 - loss: 0.9204
# Epoch 21: val_binary_accuracy improved from 0.70652 to 0.72826, saving model to ./checkpoint/cnn-7/checkpoint.model.keras
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - binary_accuracy: 0.7170 - loss: 0.9164 - val_binary_accuracy: 0.7283 - val_loss: 0.7268 - learning_rate: 0.0010
# Epoch 22/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.7138 - loss: 0.8140
# Epoch 22: val_binary_accuracy improved from 0.72826 to 0.74457, saving model to ./checkpoint/cnn-7/checkpoint.model.keras
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - binary_accuracy: 0.7141 - loss: 0.8096 - val_binary_accuracy: 0.7446 - val_loss: 0.6016 - learning_rate: 0.0010
# Epoch 23/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.7202 - loss: 0.6644
# Epoch 23: val_binary_accuracy improved from 0.74457 to 0.75000, saving model to ./checkpoint/cnn-7/checkpoint.model.keras
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - binary_accuracy: 0.7209 - loss: 0.6621 - val_binary_accuracy: 0.7500 - val_loss: 0.6787 - learning_rate: 0.0010
# Epoch 24/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.7355 - loss: 0.7028
# Epoch 24: val_binary_accuracy did not improve from 0.75000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.7361 - loss: 0.7011 - val_binary_accuracy: 0.7337 - val_loss: 0.7012 - learning_rate: 0.0010
# Epoch 25/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.6960 - loss: 0.7154
# Epoch 25: val_binary_accuracy did not improve from 0.75000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - binary_accuracy: 0.6949 - loss: 0.7159 - val_binary_accuracy: 0.7337 - val_loss: 0.5751 - learning_rate: 0.0010
# Epoch 26/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.6737 - loss: 0.6880
# Epoch 26: val_binary_accuracy did not improve from 0.75000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - binary_accuracy: 0.6755 - loss: 0.6854 - val_binary_accuracy: 0.7120 - val_loss: 0.6153 - learning_rate: 0.0010
# Epoch 27/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.7137 - loss: 0.6295
# Epoch 27: val_binary_accuracy did not improve from 0.75000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - binary_accuracy: 0.7148 - loss: 0.6270 - val_binary_accuracy: 0.6957 - val_loss: 0.5637 - learning_rate: 0.0010
# Epoch 28/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.7196 - loss: 0.6471
# Epoch 28: val_binary_accuracy did not improve from 0.75000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - binary_accuracy: 0.7208 - loss: 0.6450 - val_binary_accuracy: 0.7500 - val_loss: 0.5729 - learning_rate: 0.0010
# Epoch 29/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.7431 - loss: 0.5486
# Epoch 29: val_binary_accuracy did not improve from 0.75000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - binary_accuracy: 0.7434 - loss: 0.5478 - val_binary_accuracy: 0.7446 - val_loss: 0.5676 - learning_rate: 0.0010
# Epoch 30/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.7302 - loss: 0.5877
# Epoch 30: val_binary_accuracy did not improve from 0.75000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - binary_accuracy: 0.7309 - loss: 0.5856 - val_binary_accuracy: 0.7283 - val_loss: 0.6055 - learning_rate: 0.0010
# Epoch 31/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.7637 - loss: 0.5329
# Epoch 31: val_binary_accuracy did not improve from 0.75000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - binary_accuracy: 0.7637 - loss: 0.5332 - val_binary_accuracy: 0.7283 - val_loss: 0.6694 - learning_rate: 0.0010
# Epoch 32/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.7763 - loss: 0.5226
# Epoch 32: val_binary_accuracy did not improve from 0.75000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - binary_accuracy: 0.7765 - loss: 0.5217 - val_binary_accuracy: 0.7446 - val_loss: 0.5635 - learning_rate: 0.0010
# Epoch 33/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.7380 - loss: 0.5971
# Epoch 33: val_binary_accuracy did not improve from 0.75000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - binary_accuracy: 0.7389 - loss: 0.5940 - val_binary_accuracy: 0.7500 - val_loss: 0.6581 - learning_rate: 0.0010
# Epoch 34/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.7539 - loss: 0.5247
# Epoch 34: val_binary_accuracy improved from 0.75000 to 0.77717, saving model to ./checkpoint/cnn-7/checkpoint.model.keras
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - binary_accuracy: 0.7543 - loss: 0.5242 - val_binary_accuracy: 0.7772 - val_loss: 0.6880 - learning_rate: 0.0010
# Epoch 35/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.7992 - loss: 0.5140
# Epoch 35: val_binary_accuracy did not improve from 0.77717
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - binary_accuracy: 0.7993 - loss: 0.5143 - val_binary_accuracy: 0.7391 - val_loss: 0.5918 - learning_rate: 0.0010
# Epoch 36/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.7853 - loss: 0.4679
# Epoch 36: val_binary_accuracy did not improve from 0.77717
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - binary_accuracy: 0.7852 - loss: 0.4681 - val_binary_accuracy: 0.7337 - val_loss: 0.5809 - learning_rate: 0.0010
# Epoch 37/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.7358 - loss: 0.5359
# Epoch 37: val_binary_accuracy did not improve from 0.77717
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - binary_accuracy: 0.7363 - loss: 0.5355 - val_binary_accuracy: 0.7391 - val_loss: 0.5778 - learning_rate: 0.0010
# Epoch 38/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.7643 - loss: 0.5972
# Epoch 38: val_binary_accuracy did not improve from 0.77717
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - binary_accuracy: 0.7646 - loss: 0.5952 - val_binary_accuracy: 0.7717 - val_loss: 0.5839 - learning_rate: 0.0010
# Epoch 39/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8061 - loss: 0.5543
# Epoch 39: val_binary_accuracy did not improve from 0.77717
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - binary_accuracy: 0.8054 - loss: 0.5534 - val_binary_accuracy: 0.7717 - val_loss: 0.5851 - learning_rate: 0.0010
# Epoch 40/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.7770 - loss: 0.5005
# Epoch 40: val_binary_accuracy did not improve from 0.77717
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - binary_accuracy: 0.7775 - loss: 0.4999 - val_binary_accuracy: 0.7609 - val_loss: 0.6586 - learning_rate: 0.0010
# Epoch 41/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.7769 - loss: 0.4878
# Epoch 41: val_binary_accuracy did not improve from 0.77717
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - binary_accuracy: 0.7771 - loss: 0.4871 - val_binary_accuracy: 0.7609 - val_loss: 0.7211 - learning_rate: 0.0010
# Epoch 42/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.7908 - loss: 0.4863
# Epoch 42: val_binary_accuracy improved from 0.77717 to 0.78261, saving model to ./checkpoint/cnn-7/checkpoint.model.keras
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - binary_accuracy: 0.7909 - loss: 0.4850 - val_binary_accuracy: 0.7826 - val_loss: 0.6231 - learning_rate: 0.0010
# Epoch 43/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.7921 - loss: 0.4502
# Epoch 43: val_binary_accuracy did not improve from 0.78261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.7922 - loss: 0.4497 - val_binary_accuracy: 0.7609 - val_loss: 0.6422 - learning_rate: 0.0010
# Epoch 44/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8223 - loss: 0.4317
# Epoch 44: val_binary_accuracy did not improve from 0.78261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8220 - loss: 0.4311 - val_binary_accuracy: 0.7500 - val_loss: 0.5860 - learning_rate: 0.0010
# Epoch 45/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.7995 - loss: 0.4478
# Epoch 45: val_binary_accuracy did not improve from 0.78261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.7995 - loss: 0.4477 - val_binary_accuracy: 0.7446 - val_loss: 0.7690 - learning_rate: 0.0010
# Epoch 46/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.7862 - loss: 0.4556
# Epoch 46: val_binary_accuracy did not improve from 0.78261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.7862 - loss: 0.4549 - val_binary_accuracy: 0.7337 - val_loss: 0.9183 - learning_rate: 0.0010
# Epoch 47/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8163 - loss: 0.4249
# Epoch 47: val_binary_accuracy did not improve from 0.78261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8160 - loss: 0.4250 - val_binary_accuracy: 0.7772 - val_loss: 0.6650 - learning_rate: 0.0010
# Epoch 48/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8000 - loss: 0.4104
# Epoch 48: val_binary_accuracy did not improve from 0.78261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8004 - loss: 0.4099 - val_binary_accuracy: 0.7609 - val_loss: 0.7534 - learning_rate: 0.0010
# Epoch 49/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8280 - loss: 0.4209
# Epoch 49: val_binary_accuracy did not improve from 0.78261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8281 - loss: 0.4198 - val_binary_accuracy: 0.7826 - val_loss: 0.6834 - learning_rate: 0.0010
# Epoch 50/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8192 - loss: 0.4574
# Epoch 50: val_binary_accuracy did not improve from 0.78261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8192 - loss: 0.4566 - val_binary_accuracy: 0.7337 - val_loss: 0.5965 - learning_rate: 0.0010
# Epoch 51/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8294 - loss: 0.3766
# Epoch 51: val_binary_accuracy did not improve from 0.78261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8292 - loss: 0.3772 - val_binary_accuracy: 0.7500 - val_loss: 0.6935 - learning_rate: 0.0010
# Epoch 52/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.7841 - loss: 0.4751
# Epoch 52: val_binary_accuracy did not improve from 0.78261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.7847 - loss: 0.4734 - val_binary_accuracy: 0.7826 - val_loss: 0.6484 - learning_rate: 0.0010
# Epoch 53/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.7803 - loss: 0.5054
# Epoch 53: val_binary_accuracy did not improve from 0.78261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.7810 - loss: 0.5037 - val_binary_accuracy: 0.7391 - val_loss: 0.8680 - learning_rate: 0.0010
# Epoch 54/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.7960 - loss: 0.4509
# Epoch 54: val_binary_accuracy did not improve from 0.78261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.7964 - loss: 0.4498 - val_binary_accuracy: 0.7609 - val_loss: 0.7842 - learning_rate: 0.0010
# Epoch 55/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8018 - loss: 0.4797
# Epoch 55: val_binary_accuracy did not improve from 0.78261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8020 - loss: 0.4779 - val_binary_accuracy: 0.7772 - val_loss: 0.8467 - learning_rate: 0.0010
# Epoch 56/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8409 - loss: 0.3774
# Epoch 56: val_binary_accuracy did not improve from 0.78261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8405 - loss: 0.3769 - val_binary_accuracy: 0.7391 - val_loss: 0.8906 - learning_rate: 0.0010
# Epoch 57/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8134 - loss: 0.4355
# Epoch 57: val_binary_accuracy did not improve from 0.78261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8134 - loss: 0.4352 - val_binary_accuracy: 0.7120 - val_loss: 0.6404 - learning_rate: 0.0010
# Epoch 58/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.7819 - loss: 0.4442
# Epoch 58: val_binary_accuracy did not improve from 0.78261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.7829 - loss: 0.4436 - val_binary_accuracy: 0.7446 - val_loss: 0.9201 - learning_rate: 0.0010
# Epoch 59/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.7971 - loss: 0.4872
# Epoch 59: val_binary_accuracy did not improve from 0.78261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - binary_accuracy: 0.7974 - loss: 0.4853 - val_binary_accuracy: 0.7228 - val_loss: 0.7672 - learning_rate: 0.0010
# Epoch 60/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8347 - loss: 0.4253
# Epoch 60: val_binary_accuracy did not improve from 0.78261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8350 - loss: 0.4245 - val_binary_accuracy: 0.7554 - val_loss: 0.8062 - learning_rate: 0.0010
# Epoch 61/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8034 - loss: 0.4043
# Epoch 61: val_binary_accuracy did not improve from 0.78261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8040 - loss: 0.4048 - val_binary_accuracy: 0.7663 - val_loss: 0.6897 - learning_rate: 0.0010
# Epoch 62/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8272 - loss: 0.4021
# Epoch 62: val_binary_accuracy did not improve from 0.78261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8277 - loss: 0.4015 - val_binary_accuracy: 0.7663 - val_loss: 0.7729 - learning_rate: 0.0010
# Epoch 63/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8428 - loss: 0.3946
# Epoch 63: val_binary_accuracy did not improve from 0.78261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8427 - loss: 0.3938 - val_binary_accuracy: 0.7554 - val_loss: 0.8682 - learning_rate: 0.0010
# Epoch 64/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8339 - loss: 0.3431
# Epoch 64: val_binary_accuracy did not improve from 0.78261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8339 - loss: 0.3432 - val_binary_accuracy: 0.7446 - val_loss: 0.6517 - learning_rate: 0.0010
# Epoch 65/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8323 - loss: 0.3849
# Epoch 65: val_binary_accuracy did not improve from 0.78261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8321 - loss: 0.3845 - val_binary_accuracy: 0.7772 - val_loss: 0.7198 - learning_rate: 0.0010
# Epoch 66/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8219 - loss: 0.4154
# Epoch 66: val_binary_accuracy did not improve from 0.78261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8220 - loss: 0.4147 - val_binary_accuracy: 0.7826 - val_loss: 0.7160 - learning_rate: 0.0010
# Epoch 67/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8361 - loss: 0.3604
# Epoch 67: val_binary_accuracy did not improve from 0.78261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8358 - loss: 0.3603 - val_binary_accuracy: 0.7663 - val_loss: 0.8344 - learning_rate: 0.0010
# Epoch 68/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8619 - loss: 0.3350
# Epoch 68: val_binary_accuracy improved from 0.78261 to 0.78804, saving model to ./checkpoint/cnn-7/checkpoint.model.keras
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - binary_accuracy: 0.8615 - loss: 0.3349 - val_binary_accuracy: 0.7880 - val_loss: 0.8053 - learning_rate: 0.0010
# Epoch 69/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8455 - loss: 0.3606
# Epoch 69: val_binary_accuracy did not improve from 0.78804
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8453 - loss: 0.3607 - val_binary_accuracy: 0.7337 - val_loss: 0.5872 - learning_rate: 0.0010
# Epoch 70/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8360 - loss: 0.3421
# Epoch 70: val_binary_accuracy did not improve from 0.78804
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8366 - loss: 0.3424 - val_binary_accuracy: 0.6630 - val_loss: 0.9146 - learning_rate: 0.0010
# Epoch 71/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8577 - loss: 0.3200
# Epoch 71: val_binary_accuracy did not improve from 0.78804
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8574 - loss: 0.3207 - val_binary_accuracy: 0.7446 - val_loss: 1.0115 - learning_rate: 0.0010
# Epoch 72/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8468 - loss: 0.3236
# Epoch 72: val_binary_accuracy did not improve from 0.78804
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8469 - loss: 0.3237 - val_binary_accuracy: 0.7880 - val_loss: 0.8618 - learning_rate: 0.0010
# Epoch 73/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8691 - loss: 0.3583
# Epoch 73: val_binary_accuracy did not improve from 0.78804
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8692 - loss: 0.3576 - val_binary_accuracy: 0.7772 - val_loss: 0.6248 - learning_rate: 0.0010
# Epoch 74/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8579 - loss: 0.3472
# Epoch 74: val_binary_accuracy did not improve from 0.78804
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8575 - loss: 0.3472 - val_binary_accuracy: 0.7554 - val_loss: 1.2345 - learning_rate: 0.0010
# Epoch 75/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8520 - loss: 0.3361
# Epoch 75: val_binary_accuracy did not improve from 0.78804
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8522 - loss: 0.3357 - val_binary_accuracy: 0.7826 - val_loss: 0.7752 - learning_rate: 0.0010
# Epoch 76/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8553 - loss: 0.3245
# Epoch 76: val_binary_accuracy did not improve from 0.78804
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8556 - loss: 0.3246 - val_binary_accuracy: 0.7609 - val_loss: 0.9552 - learning_rate: 0.0010
# Epoch 77/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8544 - loss: 0.3477
# Epoch 77: val_binary_accuracy did not improve from 0.78804
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8545 - loss: 0.3472 - val_binary_accuracy: 0.7772 - val_loss: 0.7370 - learning_rate: 0.0010
# Epoch 78/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8689 - loss: 0.2908
# Epoch 78: val_binary_accuracy did not improve from 0.78804
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8689 - loss: 0.2906 - val_binary_accuracy: 0.7663 - val_loss: 0.6731 - learning_rate: 0.0010
# Epoch 79/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8685 - loss: 0.3143
# Epoch 79: val_binary_accuracy did not improve from 0.78804
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8684 - loss: 0.3141 - val_binary_accuracy: 0.7120 - val_loss: 1.0341 - learning_rate: 0.0010
# Epoch 80/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8258 - loss: 0.3279
# Epoch 80: val_binary_accuracy did not improve from 0.78804
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8267 - loss: 0.3277 - val_binary_accuracy: 0.7717 - val_loss: 0.6693 - learning_rate: 0.0010
# Epoch 81/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8758 - loss: 0.2880
# Epoch 81: val_binary_accuracy did not improve from 0.78804
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8758 - loss: 0.2888 - val_binary_accuracy: 0.7826 - val_loss: 0.7116 - learning_rate: 0.0010
# Epoch 82/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8495 - loss: 0.3263
# Epoch 82: val_binary_accuracy did not improve from 0.78804
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8500 - loss: 0.3255 - val_binary_accuracy: 0.7500 - val_loss: 0.8182 - learning_rate: 0.0010
# Epoch 83/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8651 - loss: 0.3026
# Epoch 83: val_binary_accuracy did not improve from 0.78804
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8654 - loss: 0.3023 - val_binary_accuracy: 0.6793 - val_loss: 1.2016 - learning_rate: 0.0010
# Epoch 84/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8674 - loss: 0.3105
# Epoch 84: val_binary_accuracy did not improve from 0.78804
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8677 - loss: 0.3103 - val_binary_accuracy: 0.6902 - val_loss: 1.1682 - learning_rate: 0.0010
# Epoch 85/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8655 - loss: 0.3314
# Epoch 85: val_binary_accuracy did not improve from 0.78804
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8660 - loss: 0.3300 - val_binary_accuracy: 0.7717 - val_loss: 0.7556 - learning_rate: 0.0010
# Epoch 86/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8594 - loss: 0.3351
# Epoch 86: val_binary_accuracy did not improve from 0.78804
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8597 - loss: 0.3341 - val_binary_accuracy: 0.7880 - val_loss: 0.7686 - learning_rate: 0.0010
# Epoch 87/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8724 - loss: 0.2990
# Epoch 87: val_binary_accuracy did not improve from 0.78804
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8723 - loss: 0.2992 - val_binary_accuracy: 0.7772 - val_loss: 0.8181 - learning_rate: 0.0010
# Epoch 88/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8831 - loss: 0.2425
# Epoch 88: val_binary_accuracy did not improve from 0.78804
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8831 - loss: 0.2435 - val_binary_accuracy: 0.7826 - val_loss: 0.8026 - learning_rate: 0.0010
# Epoch 89/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8692 - loss: 0.2823
# Epoch 89: val_binary_accuracy did not improve from 0.78804
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8699 - loss: 0.2816 - val_binary_accuracy: 0.7880 - val_loss: 0.7987 - learning_rate: 0.0010
# Epoch 90/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8842 - loss: 0.2792
# Epoch 90: val_binary_accuracy did not improve from 0.78804
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8848 - loss: 0.2785 - val_binary_accuracy: 0.7772 - val_loss: 0.6381 - learning_rate: 0.0010
# Epoch 91/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8746 - loss: 0.2929
# Epoch 91: val_binary_accuracy did not improve from 0.78804
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8753 - loss: 0.2918 - val_binary_accuracy: 0.7663 - val_loss: 0.6675 - learning_rate: 0.0010
# Epoch 92/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8878 - loss: 0.2583
# Epoch 92: val_binary_accuracy did not improve from 0.78804
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8878 - loss: 0.2583 - val_binary_accuracy: 0.7554 - val_loss: 0.7861 - learning_rate: 0.0010
# Epoch 93/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8761 - loss: 0.2667
# Epoch 93: val_binary_accuracy did not improve from 0.78804
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8762 - loss: 0.2666 - val_binary_accuracy: 0.7663 - val_loss: 0.8001 - learning_rate: 0.0010
# Epoch 94/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8907 - loss: 0.2583
# Epoch 94: val_binary_accuracy did not improve from 0.78804
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8906 - loss: 0.2588 - val_binary_accuracy: 0.7609 - val_loss: 0.8947 - learning_rate: 0.0010
# Epoch 95/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8733 - loss: 0.2608
# Epoch 95: val_binary_accuracy did not improve from 0.78804
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8738 - loss: 0.2605 - val_binary_accuracy: 0.7446 - val_loss: 0.8993 - learning_rate: 0.0010
# Epoch 96/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9078 - loss: 0.2175
# Epoch 96: val_binary_accuracy did not improve from 0.78804
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.9075 - loss: 0.2178 - val_binary_accuracy: 0.7663 - val_loss: 0.8421 - learning_rate: 0.0010
# Epoch 97/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8811 - loss: 0.2576
# Epoch 97: val_binary_accuracy did not improve from 0.78804
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8817 - loss: 0.2564 - val_binary_accuracy: 0.7609 - val_loss: 0.7498 - learning_rate: 0.0010
# Epoch 98/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.8665 - loss: 0.2623
# Epoch 98: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 98: val_binary_accuracy did not improve from 0.78804
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.8670 - loss: 0.2621 - val_binary_accuracy: 0.7391 - val_loss: 0.8349 - learning_rate: 0.0010
# Epoch 99/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - binary_accuracy: 0.8999 - loss: 0.2404
# Epoch 99: val_binary_accuracy improved from 0.78804 to 0.79891, saving model to ./checkpoint/cnn-7/checkpoint.model.keras
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - binary_accuracy: 0.9004 - loss: 0.2397 - val_binary_accuracy: 0.7989 - val_loss: 0.7416 - learning_rate: 2.0000e-04
# Epoch 100/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9398 - loss: 0.1763
# Epoch 100: val_binary_accuracy improved from 0.79891 to 0.80978, saving model to ./checkpoint/cnn-7/checkpoint.model.keras
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - binary_accuracy: 0.9396 - loss: 0.1760 - val_binary_accuracy: 0.8098 - val_loss: 0.8941 - learning_rate: 2.0000e-04
# Epoch 101/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9020 - loss: 0.1760
# Epoch 101: val_binary_accuracy did not improve from 0.80978
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.9023 - loss: 0.1755 - val_binary_accuracy: 0.8043 - val_loss: 0.8667 - learning_rate: 2.0000e-04
# Epoch 102/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9339 - loss: 0.1564
# Epoch 102: val_binary_accuracy did not improve from 0.80978
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.9337 - loss: 0.1569 - val_binary_accuracy: 0.7772 - val_loss: 0.8982 - learning_rate: 2.0000e-04
# Epoch 103/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9248 - loss: 0.1929
# Epoch 103: val_binary_accuracy did not improve from 0.80978
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.9250 - loss: 0.1921 - val_binary_accuracy: 0.7935 - val_loss: 0.8711 - learning_rate: 2.0000e-04
# Epoch 104/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9210 - loss: 0.1699
# Epoch 104: val_binary_accuracy did not improve from 0.80978
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.9214 - loss: 0.1694 - val_binary_accuracy: 0.8043 - val_loss: 0.8107 - learning_rate: 2.0000e-04
# Epoch 105/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9290 - loss: 0.1637
# Epoch 105: val_binary_accuracy did not improve from 0.80978
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.9293 - loss: 0.1633 - val_binary_accuracy: 0.7880 - val_loss: 0.9248 - learning_rate: 2.0000e-04
# Epoch 106/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9307 - loss: 0.1416
# Epoch 106: val_binary_accuracy did not improve from 0.80978
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.9310 - loss: 0.1415 - val_binary_accuracy: 0.7989 - val_loss: 0.9313 - learning_rate: 2.0000e-04
# Epoch 107/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9514 - loss: 0.1406
# Epoch 107: val_binary_accuracy did not improve from 0.80978
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.9513 - loss: 0.1404 - val_binary_accuracy: 0.7989 - val_loss: 0.9126 - learning_rate: 2.0000e-04
# Epoch 108/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9461 - loss: 0.1216
# Epoch 108: val_binary_accuracy did not improve from 0.80978
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.9463 - loss: 0.1216 - val_binary_accuracy: 0.7880 - val_loss: 0.9692 - learning_rate: 2.0000e-04
# Epoch 109/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9430 - loss: 0.1226
# Epoch 109: val_binary_accuracy did not improve from 0.80978
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.9428 - loss: 0.1229 - val_binary_accuracy: 0.7717 - val_loss: 1.0131 - learning_rate: 2.0000e-04
# Epoch 110/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9287 - loss: 0.1669
# Epoch 110: val_binary_accuracy did not improve from 0.80978
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.9293 - loss: 0.1660 - val_binary_accuracy: 0.8098 - val_loss: 0.9549 - learning_rate: 2.0000e-04
# Epoch 111/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9205 - loss: 0.1366
# Epoch 111: val_binary_accuracy did not improve from 0.80978
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - binary_accuracy: 0.9211 - loss: 0.1359 - val_binary_accuracy: 0.8098 - val_loss: 0.9335 - learning_rate: 2.0000e-04
# Epoch 112/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9314 - loss: 0.1498
# Epoch 112: val_binary_accuracy did not improve from 0.80978
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.9316 - loss: 0.1492 - val_binary_accuracy: 0.8043 - val_loss: 1.0386 - learning_rate: 2.0000e-04
# Epoch 113/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9399 - loss: 0.1290
# Epoch 113: val_binary_accuracy did not improve from 0.80978
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.9401 - loss: 0.1288 - val_binary_accuracy: 0.8043 - val_loss: 0.9217 - learning_rate: 2.0000e-04
# Epoch 114/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9489 - loss: 0.1413
# Epoch 114: val_binary_accuracy did not improve from 0.80978
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.9488 - loss: 0.1409 - val_binary_accuracy: 0.7989 - val_loss: 0.9350 - learning_rate: 2.0000e-04
# Epoch 115/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9332 - loss: 0.1491
# Epoch 115: val_binary_accuracy did not improve from 0.80978
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.9335 - loss: 0.1484 - val_binary_accuracy: 0.8043 - val_loss: 0.8543 - learning_rate: 2.0000e-04
# Epoch 116/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9471 - loss: 0.1134
# Epoch 116: val_binary_accuracy did not improve from 0.80978
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.9471 - loss: 0.1135 - val_binary_accuracy: 0.8043 - val_loss: 0.9773 - learning_rate: 2.0000e-04
# Epoch 117/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9555 - loss: 0.1259
# Epoch 117: val_binary_accuracy did not improve from 0.80978
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.9555 - loss: 0.1257 - val_binary_accuracy: 0.7717 - val_loss: 1.0731 - learning_rate: 2.0000e-04
# Epoch 118/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9460 - loss: 0.1265
# Epoch 118: val_binary_accuracy did not improve from 0.80978
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.9463 - loss: 0.1262 - val_binary_accuracy: 0.8043 - val_loss: 0.9990 - learning_rate: 2.0000e-04
# Epoch 119/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9494 - loss: 0.1024
# Epoch 119: val_binary_accuracy did not improve from 0.80978
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.9498 - loss: 0.1020 - val_binary_accuracy: 0.7717 - val_loss: 1.2758 - learning_rate: 2.0000e-04
# Epoch 120/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9536 - loss: 0.1251
# Epoch 120: val_binary_accuracy did not improve from 0.80978
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.9537 - loss: 0.1252 - val_binary_accuracy: 0.7989 - val_loss: 1.1101 - learning_rate: 2.0000e-04
# Epoch 121/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9505 - loss: 0.1048
# Epoch 121: val_binary_accuracy did not improve from 0.80978
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.9507 - loss: 0.1045 - val_binary_accuracy: 0.7989 - val_loss: 1.1090 - learning_rate: 2.0000e-04
# Epoch 122/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9640 - loss: 0.1012
# Epoch 122: val_binary_accuracy did not improve from 0.80978
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.9642 - loss: 0.1011 - val_binary_accuracy: 0.7935 - val_loss: 1.1250 - learning_rate: 2.0000e-04
# Epoch 123/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9542 - loss: 0.1265
# Epoch 123: val_binary_accuracy did not improve from 0.80978
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.9544 - loss: 0.1257 - val_binary_accuracy: 0.8043 - val_loss: 1.0160 - learning_rate: 2.0000e-04
# Epoch 124/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9603 - loss: 0.0964
# Epoch 124: val_binary_accuracy did not improve from 0.80978
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.9603 - loss: 0.0964 - val_binary_accuracy: 0.8098 - val_loss: 1.1141 - learning_rate: 2.0000e-04
# Epoch 125/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9591 - loss: 0.1000
# Epoch 125: val_binary_accuracy did not improve from 0.80978
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.9591 - loss: 0.1001 - val_binary_accuracy: 0.7772 - val_loss: 1.2114 - learning_rate: 2.0000e-04
# Epoch 126/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9656 - loss: 0.1019
# Epoch 126: val_binary_accuracy did not improve from 0.80978
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.9657 - loss: 0.1021 - val_binary_accuracy: 0.7826 - val_loss: 1.2130 - learning_rate: 2.0000e-04
# Epoch 127/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9719 - loss: 0.0928
# Epoch 127: val_binary_accuracy did not improve from 0.80978
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.9719 - loss: 0.0927 - val_binary_accuracy: 0.7935 - val_loss: 1.0426 - learning_rate: 2.0000e-04
# Epoch 128/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9566 - loss: 0.0880
# Epoch 128: val_binary_accuracy did not improve from 0.80978
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.9566 - loss: 0.0879 - val_binary_accuracy: 0.7880 - val_loss: 1.1273 - learning_rate: 2.0000e-04
# Epoch 129/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9503 - loss: 0.1112
# Epoch 129: val_binary_accuracy did not improve from 0.80978
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.9506 - loss: 0.1105 - val_binary_accuracy: 0.8043 - val_loss: 1.1314 - learning_rate: 2.0000e-04
# Epoch 130/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9644 - loss: 0.1067
# Epoch 130: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 130: val_binary_accuracy did not improve from 0.80978
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.9648 - loss: 0.1058 - val_binary_accuracy: 0.7935 - val_loss: 1.2599 - learning_rate: 2.0000e-04
# Epoch 131/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9671 - loss: 0.0925
# Epoch 131: val_binary_accuracy did not improve from 0.80978
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.9670 - loss: 0.0927 - val_binary_accuracy: 0.7935 - val_loss: 1.1838 - learning_rate: 4.0000e-05
# Epoch 132/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9685 - loss: 0.0724
# Epoch 132: val_binary_accuracy did not improve from 0.80978
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.9683 - loss: 0.0729 - val_binary_accuracy: 0.7989 - val_loss: 1.1683 - learning_rate: 4.0000e-05
# Epoch 133/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9663 - loss: 0.0816
# Epoch 133: val_binary_accuracy did not improve from 0.80978
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.9665 - loss: 0.0815 - val_binary_accuracy: 0.7989 - val_loss: 1.1259 - learning_rate: 4.0000e-05
# Epoch 134/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9582 - loss: 0.0815
# Epoch 134: val_binary_accuracy did not improve from 0.80978
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.9587 - loss: 0.0809 - val_binary_accuracy: 0.7989 - val_loss: 1.1184 - learning_rate: 4.0000e-05
# Epoch 135/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9724 - loss: 0.0729
# Epoch 135: val_binary_accuracy did not improve from 0.80978
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.9723 - loss: 0.0731 - val_binary_accuracy: 0.7989 - val_loss: 1.1427 - learning_rate: 4.0000e-05
# Epoch 136/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9691 - loss: 0.0810
# Epoch 136: val_binary_accuracy did not improve from 0.80978
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.9692 - loss: 0.0806 - val_binary_accuracy: 0.7935 - val_loss: 1.1424 - learning_rate: 4.0000e-05
# Epoch 137/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9703 - loss: 0.0921
# Epoch 137: val_binary_accuracy did not improve from 0.80978
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.9703 - loss: 0.0920 - val_binary_accuracy: 0.7989 - val_loss: 1.1583 - learning_rate: 4.0000e-05
# Epoch 138/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9721 - loss: 0.0759
# Epoch 138: val_binary_accuracy did not improve from 0.80978
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.9720 - loss: 0.0757 - val_binary_accuracy: 0.7935 - val_loss: 1.1639 - learning_rate: 4.0000e-05
# Epoch 139/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9670 - loss: 0.0710
# Epoch 139: val_binary_accuracy did not improve from 0.80978
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.9672 - loss: 0.0708 - val_binary_accuracy: 0.7935 - val_loss: 1.1805 - learning_rate: 4.0000e-05
# Epoch 140/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - binary_accuracy: 0.9762 - loss: 0.0669
# Epoch 140: val_binary_accuracy did not improve from 0.80978
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 0.9765 - loss: 0.0665 - val_binary_accuracy: 0.7935 - val_loss: 1.1870 - learning_rate: 4.0000e-05
# Epoch 140: early stopping
# Restoring model weights from the end of the best epoch: 100.

# %% [markdown]
# # Resultados

# %%
y_pred = model.predict(X_test, batch_size=batch_size, verbose=1)
y_pred_bool = (y_pred > 0.5).astype(int)

y_test = np.concatenate([y for x, y in X_test], axis=0)

print(classification_report(y_test, y_pred_bool))
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 322ms/step
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.74      0.79        91
#          1.0       0.77      0.88      0.82        93
#
#     accuracy                           0.81       184
#    macro avg       0.82      0.81      0.81       184
# weighted avg       0.82      0.81      0.81       184

# %%
history_frame = pd.DataFrame(history.history)
history_frame.loc[:, ["loss", "val_loss"]].plot()
history_frame.loc[:, ["binary_accuracy", "val_binary_accuracy"]].plot()
# Out:
# <Axes: >
